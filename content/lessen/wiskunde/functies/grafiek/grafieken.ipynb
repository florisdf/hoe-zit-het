# %%
import numpy as np

def f(x): return -(1/2)*x**2 + 4*x - 6
xs = np.arange(-10, 10).tolist()
ys = [f(x) for x in xs]

# %%
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
from hoezithet import graphs

p = graphs.get_plot(y_color='#19a974', x_color='#ff6300')
p.circle(xs, ys, radius=.2, color='#555555')
show(p)
# Out:
#   <div class="bk-root" id="cdb4e51a-4e01-4026-898a-7e5ff538ebd8"></div>
